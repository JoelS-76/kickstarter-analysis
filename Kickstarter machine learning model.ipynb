# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import dependencies
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
from sklearn.model_selection import train_test_split
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Read in csv dataset
kickstarter_df = pd.read_csv('Kickstarter_original_data.csv')
kickstarter_df.head()
# Out:
#    id                                               name  \
# 0   0        GIRLS STATE a new musical comedy TV project
# 1   1                        FannibalFest Fan Convention
# 2   2                          Charlie teaser completion
# 3   3  Unsure/Positive: A Dramedy Series About Life w...
# 4   4                                     Party Monsters
#
#                                                blurb        goal   \
# 0  In this new TV show "All Politics is Vocal" as...   $8,500.00
# 1  A Hannibal TV Show Fan Convention and Art Coll...  $10,275.00
# 2  Completion fund for post-production for teaser...     $500.00
# 3  We already produced the *very* beginning of th...  $10,000.00
# 4  19th century’s most notorious literary charact...  $44,000.00
#
#        pledged    outcomes country currency    deadline  launched_at  ...  \
# 0  $11,633.00   successful      US      USD  1437620400   1434931811  ...
# 1  $14,653.00   successful      US      USD  1488464683   1485872683  ...
# 2     $525.00   successful      GB      GBP  1455555083   1454691083  ...
# 3  $10,390.00   successful      US      USD  1407414107   1404822107  ...
# 4  $54,116.28   successful      US      USD  1450555279   1447963279  ...
#
#    backers_count  spotlight  Category and Subcategory Percentage Funded  \
# 0            182       True   film & video/television               137
# 1             79       True   film & video/television               143
# 2             35       True   film & video/television               105
# 3            150       True   film & video/television               104
# 4            284       True   film & video/television               123
#
#    Average Donation  Parent Category Subcategory Date Created Conversion  \
# 0             63.92     film & video  television               6/22/2015
# 1            185.48     film & video  television               1/31/2017
# 2             15.00     film & video  television                2/5/2016
# 3             69.27     film & video  television                7/8/2014
# 4            190.55     film & video  television              11/19/2015
#
#   Date Ended Conversion Years
# 0             7/23/2015  2015
# 1              3/2/2017  2017
# 2             2/15/2016  2016
# 3              8/7/2014  2014
# 4            12/19/2015  2015
#
# [5 rows x 21 columns]

# %%
# Check data types
kickstarter_df.dtypes
# Out:
# id                            int64
# name                         object
# blurb                        object
#  goal                        object
# pledged                      object
# outcomes                     object
# country                      object
# currency                     object
# deadline                      int64
# launched_at                   int64
# staff_pick                     bool
# backers_count                 int64
# spotlight                      bool
# Category and Subcategory     object
# Percentage Funded             int64
# Average Donation            float64
# Parent Category              object
# Subcategory                  object
# Date Created Conversion      object
# Date Ended Conversion        object
# Years                         int64
# dtype: object

# %%
# drop dollar signs from pledged column
kickstarter_df['pledged'] = kickstarter_df['pledged'].str.replace('$', '')

# %%
# drop dollar signs from goal column
kickstarter_df[' goal '] = kickstarter_df[' goal '].str.replace('$', '')

# %%
kickstarter_df.head()
# Out:
#    id                                               name  \
# 0   0        GIRLS STATE a new musical comedy TV project
# 1   1                        FannibalFest Fan Convention
# 2   2                          Charlie teaser completion
# 3   3  Unsure/Positive: A Dramedy Series About Life w...
# 4   4                                     Party Monsters
#
#                                                blurb       goal      pledged  \
# 0  In this new TV show "All Politics is Vocal" as...   8,500.00   11,633.00
# 1  A Hannibal TV Show Fan Convention and Art Coll...  10,275.00   14,653.00
# 2  Completion fund for post-production for teaser...     500.00      525.00
# 3  We already produced the *very* beginning of th...  10,000.00   10,390.00
# 4  19th century’s most notorious literary charact...  44,000.00   54,116.28
#
#      outcomes country currency    deadline  launched_at  ...  backers_count  \
# 0  successful      US      USD  1437620400   1434931811  ...            182
# 1  successful      US      USD  1488464683   1485872683  ...             79
# 2  successful      GB      GBP  1455555083   1454691083  ...             35
# 3  successful      US      USD  1407414107   1404822107  ...            150
# 4  successful      US      USD  1450555279   1447963279  ...            284
#
#    spotlight  Category and Subcategory Percentage Funded  Average Donation  \
# 0       True   film & video/television               137             63.92
# 1       True   film & video/television               143            185.48
# 2       True   film & video/television               105             15.00
# 3       True   film & video/television               104             69.27
# 4       True   film & video/television               123            190.55
#
#    Parent Category Subcategory Date Created Conversion Date Ended Conversion  \
# 0     film & video  television               6/22/2015             7/23/2015
# 1     film & video  television               1/31/2017              3/2/2017
# 2     film & video  television                2/5/2016             2/15/2016
# 3     film & video  television                7/8/2014              8/7/2014
# 4     film & video  television              11/19/2015            12/19/2015
#
#   Years
# 0  2015
# 1  2017
# 2  2016
# 3  2014
# 4  2015
#
# [5 rows x 21 columns]

# %%
# drop commas from goal and pledged columns
kickstarter_df[' goal '] = kickstarter_df[' goal '].str.replace(',', '')
kickstarter_df['pledged'] = kickstarter_df['pledged'].str.replace(',', '')

# %%
# Remove spaces from goal column name
kickstarter_df.rename(columns={' goal ' : 'goal'}, inplace=True)

# %%
# drop blurb and categorical columns
kickstarter_df.drop('blurb', axis=1, inplace=True)
kickstarter_df.drop('Category and Subcategory', axis=1, inplace=True)
kickstarter_df.drop('Parent Category', axis=1, inplace=True)
kickstarter_df.drop('Subcategory', axis=1, inplace=True)

# %%
kickstarter_df.head()
# Out:
#    id                                               name       goal  \
# 0   0        GIRLS STATE a new musical comedy TV project   8500.00
# 1   1                        FannibalFest Fan Convention  10275.00
# 2   2                          Charlie teaser completion    500.00
# 3   3  Unsure/Positive: A Dramedy Series About Life w...  10000.00
# 4   4                                     Party Monsters  44000.00
#
#      pledged    outcomes country currency    deadline  launched_at  \
# 0  11633.00   successful      US      USD  1437620400   1434931811
# 1  14653.00   successful      US      USD  1488464683   1485872683
# 2    525.00   successful      GB      GBP  1455555083   1454691083
# 3  10390.00   successful      US      USD  1407414107   1404822107
# 4  54116.28   successful      US      USD  1450555279   1447963279
#
#    staff_pick  backers_count  spotlight  Percentage Funded  Average Donation  \
# 0       False            182       True                137             63.92
# 1       False             79       True                143            185.48
# 2       False             35       True                105             15.00
# 3       False            150       True                104             69.27
# 4       False            284       True                123            190.55
#
#   Date Created Conversion Date Ended Conversion  Years
# 0               6/22/2015             7/23/2015   2015
# 1               1/31/2017              3/2/2017   2017
# 2                2/5/2016             2/15/2016   2016
# 3                7/8/2014              8/7/2014   2014
# 4              11/19/2015            12/19/2015   2015

# %%
# drop id
kickstarter_df.drop('id', axis=1, inplace=True)

# %%
# drop pct funded column to remove the simple equation from the model
kickstarter_df.drop('Percentage Funded', axis=1, inplace=True)

# %%
# recheck data types
kickstarter_df.dtypes
# Out:
# name                        object
# goal                        object
# pledged                     object
# outcomes                    object
# country                     object
# currency                    object
# deadline                     int64
# launched_at                  int64
# staff_pick                    bool
# backers_count                int64
# spotlight                     bool
# Average Donation           float64
# Date Created Conversion     object
# Date Ended Conversion       object
# Years                        int64
# dtype: object

# %%
# Convert goal and pledged to float
g = kickstarter_df['goal']
kickstarter_df.goal = pd.to_numeric(g)

# %%
p = kickstarter_df['pledged']
kickstarter_df.pledged = pd.to_numeric(p)

# %%
# check types
kickstarter_df.dtypes
# Out:
# name                        object
# goal                       float64
# pledged                    float64
# outcomes                    object
# country                     object
# currency                    object
# deadline                     int64
# launched_at                  int64
# staff_pick                    bool
# backers_count                int64
# spotlight                     bool
# Average Donation           float64
# Date Created Conversion     object
# Date Ended Conversion       object
# Years                        int64
# dtype: object

# %%
# drop null values
kickstarter_df.dropna()
# Out:
#                                                    name     goal   pledged  \
# 0           GIRLS STATE a new musical comedy TV project   8500.0  11633.00
# 1                           FannibalFest Fan Convention  10275.0  14653.00
# 2                             Charlie teaser completion    500.0    525.00
# 3     Unsure/Positive: A Dramedy Series About Life w...  10000.0  10390.00
# 4                                        Party Monsters  44000.0  54116.28
# ...                                                 ...      ...       ...
# 4109                                       Jack the Lad    500.0      0.00
# 4110        Take Tartuffe to Edinburgh Fringe Festival!    300.0     86.00
# 4111                                     REBORN IN LOVE   3000.0     94.00
# 4112     A Great New Controversial Play - "The Divide".   2500.0      1.00
# 4113                  The Toy Box by Anthony H. Wallace   1500.0      3.00
#
#         outcomes country currency    deadline  launched_at  staff_pick  \
# 0     successful      US      USD  1437620400   1434931811       False
# 1     successful      US      USD  1488464683   1485872683       False
# 2     successful      GB      GBP  1455555083   1454691083       False
# 3     successful      US      USD  1407414107   1404822107       False
# 4     successful      US      USD  1450555279   1447963279       False
# ...          ...     ...      ...         ...          ...         ...
# 4109      failed      GB      GBP  1448805404   1446209804       False
# 4110      failed      GB      GBP  1469113351   1463929351       False
# 4111      failed      US      USD  1424747740   1422155740       False
# 4112      failed      IE      EUR  1456617600   1454280186       False
# 4113      failed      US      USD  1452234840   1450619123       False
#
#       backers_count  spotlight  Average Donation Date Created Conversion  \
# 0               182       True             63.92               6/22/2015
# 1                79       True            185.48               1/31/2017
# 2                35       True             15.00                2/5/2016
# 3               150       True             69.27                7/8/2014
# 4               284       True            190.55              11/19/2015
# ...             ...        ...               ...                     ...
# 4109              0      False              0.00              10/30/2015
# 4110              6      False             14.33               5/22/2016
# 4111              6      False             15.67               1/25/2015
# 4112              1      False              1.00               1/31/2016
# 4113              3      False              1.00              12/20/2015
#
#      Date Ended Conversion  Years
# 0                7/23/2015   2015
# 1                 3/2/2017   2017
# 2                2/15/2016   2016
# 3                 8/7/2014   2014
# 4               12/19/2015   2015
# ...                    ...    ...
# 4109            11/29/2015   2015
# 4110             7/21/2016   2016
# 4111             2/24/2015   2015
# 4112             2/28/2016   2016
# 4113              1/8/2016   2015
#
# [4114 rows x 15 columns]

# %%
# convert True/False values to boolean
kickstarter_df[['staff_pick', 'spotlight']] = (kickstarter_df[['staff_pick', 'spotlight']] == True).astype(int)

# %%
kickstarter_df.head()
# Out:
#                                                 name     goal   pledged  \
# 0        GIRLS STATE a new musical comedy TV project   8500.0  11633.00
# 1                        FannibalFest Fan Convention  10275.0  14653.00
# 2                          Charlie teaser completion    500.0    525.00
# 3  Unsure/Positive: A Dramedy Series About Life w...  10000.0  10390.00
# 4                                     Party Monsters  44000.0  54116.28
#
#      outcomes country currency    deadline  launched_at  staff_pick  \
# 0  successful      US      USD  1437620400   1434931811           0
# 1  successful      US      USD  1488464683   1485872683           0
# 2  successful      GB      GBP  1455555083   1454691083           0
# 3  successful      US      USD  1407414107   1404822107           0
# 4  successful      US      USD  1450555279   1447963279           0
#
#    backers_count  spotlight  Average Donation Date Created Conversion  \
# 0            182          1             63.92               6/22/2015
# 1             79          1            185.48               1/31/2017
# 2             35          1             15.00                2/5/2016
# 3            150          1             69.27                7/8/2014
# 4            284          1            190.55              11/19/2015
#
#   Date Ended Conversion  Years
# 0             7/23/2015   2015
# 1              3/2/2017   2017
# 2             2/15/2016   2016
# 3              8/7/2014   2014
# 4            12/19/2015   2015

# %%
#drop other unnecessary text columns
kickstarter_df.drop('name', axis=1, inplace=True)
kickstarter_df.drop('Date Created Conversion', axis=1, inplace=True)
kickstarter_df.drop('Date Ended Conversion', axis=1, inplace=True)

# %%
kickstarter_df.head()
# Out:
#       goal   pledged    outcomes country currency    deadline  launched_at  \
# 0   8500.0  11633.00  successful      US      USD  1437620400   1434931811
# 1  10275.0  14653.00  successful      US      USD  1488464683   1485872683
# 2    500.0    525.00  successful      GB      GBP  1455555083   1454691083
# 3  10000.0  10390.00  successful      US      USD  1407414107   1404822107
# 4  44000.0  54116.28  successful      US      USD  1450555279   1447963279
#
#    staff_pick  backers_count  spotlight  Average Donation  Years
# 0           0            182          1             63.92   2015
# 1           0             79          1            185.48   2017
# 2           0             35          1             15.00   2016
# 3           0            150          1             69.27   2014
# 4           0            284          1            190.55   2015

# %%
kickstarter_df = kickstarter_df[kickstarter_df.outcomes != 'live']

# %%
kickstarter_df = kickstarter_df[kickstarter_df.outcomes != 'canceled']

# %%
# check for nulls
kickstarter_df.isnull().sum().sum()
# Out:
# 0

# %%
#Define target variable
target= 'outcomes'

# %%
# Create features
X = kickstarter_df.drop(columns='outcomes')
X = pd.get_dummies(X)

# Create target
y = kickstarter_df.loc[:, target].copy()

# %%
X.describe()
# Out:
#                goal       pledged      deadline   launched_at   staff_pick  \
# count  3.715000e+03  3.715000e+03  3.715000e+03  3.715000e+03  3715.000000
# mean   3.074311e+04  1.169171e+04  1.418824e+09  1.415960e+09     0.148587
# std    2.701060e+05  5.888240e+04  4.833379e+07  4.847948e+07     0.355729
# min    1.000000e+00  0.000000e+00  1.249932e+09  1.242533e+09     0.000000
# 25%    2.000000e+03  2.145000e+02  1.402470e+09  1.399895e+09     0.000000
# 50%    5.000000e+03  1.908000e+03  1.427310e+09  1.424281e+09     0.000000
# 75%    1.500000e+04  6.300500e+03  1.454433e+09  1.452008e+09     0.000000
# max    1.000000e+07  2.344135e+06  1.489536e+09  1.488823e+09     1.000000
#
#        backers_count    spotlight  Average Donation        Years   country_AT  \
# count    3715.000000  3715.000000       3715.000000  3715.000000  3715.000000
# mean      121.646030     0.588156         79.929612  2014.386003     0.001346
# std       654.595678     0.492233        138.241661     1.552394     0.036667
# min         0.000000     0.000000          0.000000  2009.000000     0.000000
# 25%         5.000000     0.000000         27.145000  2014.000000     0.000000
# 50%        28.000000     1.000000         53.340000  2015.000000     0.000000
# 75%        82.500000     1.000000         91.220000  2016.000000     0.000000
# max     26457.000000     1.000000       3000.000000  2017.000000     1.000000
#
#        ...  currency_DKK  currency_EUR  currency_GBP  currency_HKD  \
# count  ...   3715.000000   3715.000000   3715.000000   3715.000000
# mean   ...      0.002692      0.041184      0.153701      0.000538
# std    ...      0.051820      0.198743      0.360711      0.023199
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#        currency_MXN  currency_NOK  currency_NZD  currency_SEK  currency_SGD  \
# count   3715.000000   3715.000000   3715.000000   3715.000000   3715.000000
# mean       0.002153      0.001884      0.002153      0.004307      0.000269
# std        0.046361      0.043373      0.046361      0.065494      0.016407
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        currency_USD
# count   3715.000000
# mean       0.739704
# std        0.438855
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 43 columns]

# %%
# Check the balance of the target values
y.value_counts()
# Out:
# successful    2185
# failed        1530
# Name: outcomes, dtype: int64

# %%
#Split the data for training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.preprocessing import StandardScaler

#Create a StandardScaler instance
scaler = StandardScaler()
# Fit the Standard Scaler with the training data
X_scaler = scaler.fit(X_train)

# Scaling the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

brf_model = BalancedRandomForestClassifier(n_estimators = 100, random_state = 1)
brf_model = brf_model.fit(X_train_scaled, y_train)

y_pred = brf_model.predict(X_test_scaled)

# %%
#from sklearn.metrics import accuracy_score on training set
y_pred_train = brf_model.predict(X_train_scaled)
balanced_accuracy_score(y_train, y_pred_train)
# Out:
# 1.0

# %%
# Calculated the balanced accuracy score on test set
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
# Display the confusion matrix
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
# Calculating the confusion matrix.
cm = confusion_matrix(y_test, y_pred)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0          392            0
# Actual 1            0          537

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#      failed       1.00      1.00      1.00      1.00      1.00      1.00       392
#  successful       1.00      1.00      1.00      1.00      1.00      1.00       537
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00       929

# %%
importances = sorted(zip(brf_model.feature_importances_, X.columns), reverse=True)
importances
# Out:
# [(0.5361612837299523, 'spotlight'),
#  (0.16300095449634544, 'backers_count'),
#  (0.14124328694767493, 'pledged'),
#  (0.05638612719592101, 'Average Donation'),
#  (0.053413201987878155, 'goal'),
#  (0.013726626252612034, 'launched_at'),
#  (0.011340385923171688, 'staff_pick'),
#  (0.010797098866611388, 'deadline'),
#  (0.005113309327372972, 'Years'),
#  (0.0012959284301771934, 'currency_GBP'),
#  (0.0010343237056213764, 'country_GB'),
#  (0.0009300889827082525, 'currency_USD'),
#  (0.0008809931253104612, 'country_US'),
#  (0.0006248925874543884, 'currency_EUR'),
#  (0.00045947273362908467, 'country_NL'),
#  (0.0004288680614054219, 'currency_CAD'),
#  (0.0003871464005802391, 'country_AU'),
#  (0.0003823112828322262, 'currency_AUD'),
#  (0.00036751973394308693, 'country_CA'),
#  (0.0002954826059156006, 'country_MX'),
#  (0.0002752517987934019, 'country_DE'),
#  (0.00024693609782461886, 'currency_MXN'),
#  (0.000234060827850118, 'country_IT'),
#  (0.0001703023723795907, 'country_ES'),
#  (0.00011014939266322208, 'country_IE'),
#  (0.00010535685744464729, 'country_FR'),
#  (9.78827554926461e-05, 'currency_SEK'),
#  (9.419593624855224e-05, 'country_DK'),
#  (7.811370309546885e-05, 'currency_NOK'),
#  (6.862505510549546e-05, 'country_NO'),
#  (6.367120259814394e-05, 'currency_DKK'),
#  (5.2382305958860265e-05, 'country_CH'),
#  (3.800958327767208e-05, 'country_AT'),
#  (2.964849858824015e-05, 'country_SE'),
#  (2.0089749923607462e-05, 'country_LU'),
#  (1.3447229838345244e-05, 'country_HK'),
#  (1.3183625427483107e-05, 'currency_CHF'),
#  (1.0974862054230673e-05, 'currency_NZD'),
#  (7.304830708220236e-06, 'country_NZ'),
#  (1.1010641797854137e-06, 'country_BE'),
#  (9.873430344809345e-09, 'country_SG'),
#  (0.0, 'currency_SGD'),
#  (0.0, 'currency_HKD')]
